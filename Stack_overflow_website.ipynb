# %%
import pandas as pd

stack_surveys =  pd.read_csv('survey_results_public.csv')
stack_surveys
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
value = stack_surveys.columns

# %%
import random
Sample_data = [
    'Age',
    'Country',
    'YearsCode',
    'Currency',
    'LearnCode',
    'Industry',
    'YearsCodePro',
    'SurveyLength',
    'ResponseId',
    'Knowledge_8',
     'MiscTechWantToWorkWith',
     'PlatformHaveWorkedWith',
     'AISearchWantToWorkWith',
     'MiscTechHaveWorkedWith',
     'OfficeStackAsyncHaveWorkedWith',
     'TimeAnswering',
     'LearnCodeOnline',
     'Knowledge_7'
    ]

# %%
Sample_data
# Out:
# ['Age',
#  'Country',
#  'YearsCode',
#  'Currency',
#  'LearnCode',
#  'Industry',
#  'YearsCodePro',
#  'SurveyLength',
#  'ResponseId',
#  'Knowledge_8',
#  'MiscTechWantToWorkWith',
#  'PlatformHaveWorkedWith',
#  'AISearchWantToWorkWith',
#  'MiscTechHaveWorkedWith',
#  'OfficeStackAsyncHaveWorkedWith',
#  'TimeAnswering',
#  'LearnCodeOnline',
#  'Knowledge_7']

# %%
survey_data = stack_surveys[Sample_data].copy()
survey_data
# Out:
#                       Age                       Country YearsCode  \
# 0         18-24 years old                           NaN       NaN
# 1         25-34 years old      United States of America        18
# 2         45-54 years old      United States of America        27
# 3         25-34 years old      United States of America        12
# 4         25-34 years old                   Philippines         6
# ...                   ...                           ...       ...
# 89179     25-34 years old                        Brazil        20
# 89180     18-24 years old                       Romania         5
# 89181   Prefer not to say                        Israel        10
# 89182  Under 18 years old                   Switzerland         3
# 89183     35-44 years old  Iran, Islamic Republic of...        17
#
#                         Currency  \
# 0                            NaN
# 1      USD\tUnited States dollar
# 2      USD\tUnited States dollar
# 3      USD\tUnited States dollar
# ...

# %%
survey_data.YearsCode.unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 'Less than 1 year', '16', '33', '22',
#        '30', '32', '7', '35', '28', '40', '17', '29', '19',
#        'More than 50 years', '9', '38', '26', '34', '25', '2', '45', '23',
#        '31', '43', '1', '48', '41', '50', '39', '42', '37', '36', '44',
#        '46', '49', '47'], dtype=object)

# %%
survey_data['YearsCode'] = pd.to_numeric(survey_data.YearsCode, errors='coerce')
survey_data.YearsCode.unique()
# Out:
# array([nan, 18., 27., 12.,  6., 21.,  4.,  5., 20., 14., 10., 15., 11.,
#         3., 24.,  8., 13., 16., 33., 22., 30., 32.,  7., 35., 28., 40.,
#        17., 29., 19.,  9., 38., 26., 34., 25.,  2., 45., 23., 31., 43.,
#         1., 48., 41., 50., 39., 42., 37., 36., 44., 46., 49., 47.])

# %%
survey_data.drop(survey_data[survey_data.YearsCode < 10].index, inplace=True)
survey_data.YearsCode.unique()
# Out:
# array([nan, 18., 27., 12., 21., 20., 14., 10., 15., 11., 24., 13., 16.,
#        33., 22., 30., 32., 35., 28., 40., 17., 29., 19., 38., 26., 34.,
#        25., 45., 23., 31., 43., 48., 41., 50., 39., 42., 37., 36., 44.,
#        46., 49., 47.])

# %%
survey_data.YearsCodePro.unique()
# Out:
# array([nan, '9', '23', '7', '21', '15', '3', '10', '6', '14', '5', '19',
#        '13', '2', '4', '16', '28', '30', '11', '8', '25', '32', '24',
#        '40', '17', '45', '29', '12', '31', '20', 'Less than 1 year', '18',
#        '50', '27', '43', '22', '26', '38', '33', '44', '35', '34', '37',
#        '42', '41', 'More than 50 years', '47', '1', '36', '39', '48',
#        '46', '49'], dtype=object)

# %%
survey_data['YearsCodePro'] = pd.to_numeric(survey_data.YearsCodePro, errors='coerce')

survey_data.drop(survey_data[survey_data.YearsCodePro < 10].index, inplace=True)
survey_data.drop(survey_data[survey_data.YearsCodePro > 100].index, inplace=True)
survey_data.YearsCodePro.unique()
# Out:
# array([nan, 23., 21., 15., 10., 14., 19., 13., 16., 28., 30., 11., 25.,
#        32., 24., 40., 17., 45., 29., 12., 31., 20., 18., 50., 27., 43.,
#        22., 26., 38., 33., 44., 35., 34., 37., 42., 41., 47., 36., 39.,
#        48., 46., 49.])

# %%
survey_data.TimeAnswering.unique()
# Out:
# array([nan, '30-60 minutes a day', '15-30 minutes a day',
#        'Less than 15 minutes a day', '60-120 minutes a day',
#        'Over 120 minutes a day'], dtype=object)

# %%
survey_data.TimeAnswering
# Out:
# 0                               NaN
# 2               30-60 minutes a day
# 5               15-30 minutes a day
# 8                               NaN
# 15              15-30 minutes a day
#                     ...
# 89173    Less than 15 minutes a day
# 89177           30-60 minutes a day
# 89178          60-120 minutes a day
# 89181                           NaN
# 89183           30-60 minutes a day
# Name: TimeAnswering, Length: 38494, dtype: object

# %%
survey_data
# Out:
#                      Age                                            Country  \
# 0        18-24 years old                                                NaN
# 2        45-54 years old                           United States of America
# 5        35-44 years old  United Kingdom of Great Britain and Northern I...
# 8        45-54 years old                                            Finland
# 15       35-44 years old                                            Germany
# ...                  ...                                                ...
# 89173    35-44 years old                                Trinidad and Tobago
# 89177    35-44 years old                                             Mexico
# 89178    45-54 years old                           United States of America
# 89181  Prefer not to say                                             Israel
# 89183    35-44 years old                       Iran, Islamic Republic of...
#
#        YearsCode                   Currency  \
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')

# %%
matplotlib.rcParams['figure.figsize'] = (9,5)

# %%
stack_raw = pd.read_csv('survey_results_schema.csv', index_col='qname').question
stack_raw
# Out:
# qname
# S0             <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                       Browser Meta Info
# Q310           <div><span style="font-size:19px;"><strong>You...
# Q120
# S1             <span style="font-size:22px; font-family: aria...
#                                      ...
# Knowledge_7    Waiting on answers to questions often causes i...
# Knowledge_8    I feel like I have the tools and/or resources ...
# Frequency_1    Needing help from people outside of your immed...
# Frequency_2    Interacting with people outside of your immedi...
# Frequency_3    Encountering knowledge silos (where one indivi...
# Name: question, Length: 78, dtype: object

# %%
# schema = stack_raw[Sample_data]
stack_raw.Country
# Out:
# 'Where do you live? <span style="font-weight: bolder;">*</span>'

# %%
survey_data.Country.nunique()
# Out:
# 164

# %%
top_country = survey_data.Country.value_counts().head(10)
top_country
# Out:
# Country
# United States of America                                9501
# Germany                                                 3187
# United Kingdom of Great Britain and Northern Ireland    2840
# Canada                                                  1691
# India                                                   1173
# France                                                  1164
# Australia                                               1130
# Netherlands                                             1108
# Poland                                                   914
# Spain                                                    879
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 75)
plt.title(stack_raw.Country)

sns.barplot(top_country);

# %%
plt.figure(figsize = (12,6))
# plt.xticks(rotation = 75)
plt.title(stack_raw.Age)
plt.xlabel('Age')
plt.ylabel('Number of Responses ')

plt.hist(stack_surveys.Age);

# %%
import numpy as np
industry_data = survey_data.Industry.value_counts()
industry_data

# plt.pie(Industry_data, industry_data = survey_data.Industry.value_counts()
plt.figure(figsize = (12,6))
# Set the title for the pie chart
# plt.title(survey_data.Industry)
plt.xticks(rotation = 80)
# Plot the pie chart
sns.barplot(industry_data);

# %%
plt.pie(top_country, labels = top_country.index, autopct='%1.1f%%');

# %%
survey_data
# Out:
#                      Age                                            Country  \
# 0        18-24 years old                                                NaN
# 2        45-54 years old                           United States of America
# 5        35-44 years old  United Kingdom of Great Britain and Northern I...
# 8        45-54 years old                                            Finland
# 15       35-44 years old                                            Germany
# ...                  ...                                                ...
# 89173    35-44 years old                                Trinidad and Tobago
# 89177    35-44 years old                                             Mexico
# 89178    45-54 years old                           United States of America
# 89181  Prefer not to say                                             Israel
# 89183    35-44 years old                       Iran, Islamic Republic of...
#
#        YearsCode                   Currency  \
# ...

# %%
survey_data['EdLevel'] = stack_surveys.EdLevel.copy()

# %%
# value = survey_data.EdLevel.value_counts()

# plt.ylabel (None)
plt.figure(figsize = (12,6))
plt.xticks(rotation = 75);
sns.countplot(y=survey_data.EdLevel);

# %%
stack_surveys.Employment
stack_raw.Employment
# Out:
# 'Which of the following best describes your current employment status? Select all that apply.'
